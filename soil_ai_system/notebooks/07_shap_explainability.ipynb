# %% [markdown]
# # SHAP Explainability
# Generate summary and waterfall plots for XGBoost and DNN.

# %%
import numpy as np
import joblib
from explainability.shap_engine import explain_xgboost
from config import SAVED_MODELS_PATH, FEATURE_COLS

model = joblib.load(f'{SAVED_MODELS_PATH}xgboost_crop.pkl')
# Replace X_train and X_instance with real data arrays
# explain_xgboost(model, X_train, X_instance, FEATURE_COLS)
